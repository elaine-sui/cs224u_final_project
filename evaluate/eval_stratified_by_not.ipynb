# %%
from eval_utils import get_metrics_dict_for_path_selection_type, plot_bar_chart

ROOT = "/sailhome/esui/cs224u_final_project/prontoqa_output/fictional"

# %%
# Each plot is for a single hop number
# Same thing as usual otherwise
path_selection = "longest"
restrict_type = "not_only"
k = 5
aggregate_path_glob = f'{ROOT}/aggregated/**/summary/merge_answer_hard_*_path_select_{path_selection}_{k}hop.pkl'

metrics_dict, aggregation_types, merge_cot_types = get_metrics_dict_for_path_selection_type(aggregate_path_glob, path_selection, restrict_type)
columns = ['Aggregation Type'] + merge_cot_types

metric = "avg_label_acc"
plot_bar_chart(metric, columns, metrics_dict, aggregation_types, merge_cot_types, title=f"{k} hop {metric} restrict {restrict_type}")
# Out:
# ================================================================================
# intersection max: 0.9622641509433962
# majority max: 0.9622641509433962
# longest max: 0.9622641509433962
# union max: 0.9622641509433962
# ================================================================================
# single_backward_neg max: 0.9622641509433962
# double_backward_negation max: 0.9622641509433962
# single_forward_neg max: 0.9622641509433962
# double_forward_negation max: 0.9622641509433962
# backward_negation max: 0.9056603773584906
# forward_negation max: 0.9056603773584906
# baseline max: 0.8679245283018868
# direction max: 0.8490566037735849
# single_baseline max: 0.8490566037735849
# single_forward max: 0.8113207547169812
# all max: 0.6792452830188679
# forward_randomized_order max: 0.6415094339622641
# forward_all max: 0.6415094339622641
# backward_all max: 0.6226415094339622
# single_backward max: 0.6037735849056604
# backward_randomized_order max: 0.49056603773584906

# %%
metric = "avg_cot_acc"
plot_bar_chart(metric, columns, metrics_dict, aggregation_types, merge_cot_types, title=f"{k} hop {metric} restrict {restrict_type}")
# Out:
# ================================================================================
# intersection max: 0.2641509433962264
# majority max: 0.2641509433962264
# longest max: 0.2641509433962264
# union max: 0.2641509433962264
# ================================================================================
# single_backward_neg max: 0.2641509433962264
# double_backward_negation max: 0.2641509433962264
# forward_negation max: 0.2641509433962264
# single_forward_neg max: 0.2641509433962264
# double_forward_negation max: 0.2641509433962264
# backward_negation max: 0.1509433962264151
# single_forward max: 0.1509433962264151
# forward_all max: 0.1320754716981132
# baseline max: 0.1320754716981132
# single_baseline max: 0.1320754716981132
# forward_randomized_order max: 0.11320754716981132
# direction max: 0.11320754716981132
# backward_all max: 0.11320754716981132
# all max: 0.09433962264150944
# backward_randomized_order max: 0.05660377358490566
# single_backward max: 0.0

# %%
restrict_type = "no_not_only"
metrics_dict, aggregation_types, merge_cot_types = get_metrics_dict_for_path_selection_type(aggregate_path_glob, path_selection, restrict_type)
columns = ['Aggregation Type'] + merge_cot_types

metric = "avg_label_acc"
plot_bar_chart(metric, columns, metrics_dict, aggregation_types, merge_cot_types, title=f"{k} hop {metric} restrict {restrict_type}")
# Out:
# ================================================================================
# intersection max: 0.9148936170212766
# majority max: 0.9148936170212766
# longest max: 0.9148936170212766
# union max: 0.9148936170212766
# ================================================================================
# forward_all max: 0.9148936170212766
# forward_negation max: 0.9148936170212766
# baseline max: 0.9148936170212766
# single_baseline max: 0.9148936170212766
# forward_randomized_order max: 0.8936170212765957
# direction max: 0.8936170212765957
# backward_negation max: 0.8936170212765957
# single_forward max: 0.8936170212765957
# double_forward_negation max: 0.8936170212765957
# all max: 0.8936170212765957
# single_backward_neg max: 0.8723404255319149
# single_forward_neg max: 0.8723404255319149
# single_backward max: 0.7659574468085106
# double_backward_negation max: 0.7659574468085106
# backward_all max: 0.6808510638297872
# backward_randomized_order max: 0.6595744680851063

# %%
metric = "avg_cot_acc"
plot_bar_chart(metric, columns, metrics_dict, aggregation_types, merge_cot_types, title=f"{k} hop {metric} restrict {restrict_type}")
# Out:
# ================================================================================
# majority max: 0.2608695652173913
# union max: 0.2608695652173913
# intersection max: 0.2391304347826087
# longest max: 0.2391304347826087
# ================================================================================
# forward_randomized_order max: 0.2608695652173913
# forward_negation max: 0.2608695652173913
# backward_negation max: 0.2391304347826087
# single_forward max: 0.2391304347826087
# double_forward_negation max: 0.2391304347826087
# single_baseline max: 0.2391304347826087
# direction max: 0.21739130434782608
# forward_all max: 0.21739130434782608
# baseline max: 0.21739130434782608
# all max: 0.1956521739130435
# single_backward_neg max: 0.17391304347826086
# backward_all max: 0.17391304347826086
# single_forward_neg max: 0.17391304347826086
# backward_randomized_order max: 0.06521739130434782
# single_backward max: 0.0
# double_backward_negation max: 0.0
