# %%
from eval_utils import get_metrics_dict_for_path_selection_type, plot_bar_chart

ROOT = "/sailhome/esui/cs224u_final_project/prontoqa_output/fictional"
# Out:
# Not loading Cohere because it is not installed.

# %%
# Each plot is for a single hop number
# Same thing as usual otherwise
path_selection = "longest"
k = 1
aggregate_path_glob = f'{ROOT}/aggregated/**/merge_cot_of_majority_answer/summary/merge_answer_hard_*_path_select_{path_selection}_{k}hop.pkl'

metrics_dict, aggregation_types, merge_cot_types = get_metrics_dict_for_path_selection_type(aggregate_path_glob, path_selection)
columns = ['Aggregation Type'] + merge_cot_types

metric = "avg_label_acc"
plot_bar_chart(metric, columns, metrics_dict, aggregation_types, merge_cot_types, title=f"{k} hop {metric}")
# Out:
# ...
# of_majority_answer/summary/merge_answer_hard_merge_cot_none max: 0.95
# of_majority_answer/summary/merge_answer_hard_merge_cot_intersection max: 0.95
# of_majority_answer/summary/merge_answer_hard_merge_cot_longest max: 0.95
# of_majority_answer/summary/merge_answer_hard_merge_cot_union max: 0.95
# ...
# backward_negation max: 0.95
# single_backward_neg max: 0.94
# single_forward_neg max: 0.94
# forward_negation max: 0.93
# baseline max: 0.93
# single_baseline max: 0.93
# direction max: 0.92
# single_backward max: 0.9
# single_forward max: 0.9

# %%
metric = "avg_cot_acc"
plot_bar_chart(metric, columns, metrics_dict, aggregation_types, merge_cot_types, title=f"{k} hop {metric}")
# Out:
# ...
# of_majority_answer/summary/merge_answer_hard_merge_cot_none max: 0.71
# of_majority_answer/summary/merge_answer_hard_merge_cot_intersection max: 0.71
# of_majority_answer/summary/merge_answer_hard_merge_cot_longest max: 0.71
# of_majority_answer/summary/merge_answer_hard_merge_cot_union max: 0.71
# ...
# single_backward_neg max: 0.71
# backward_negation max: 0.71
# single_forward_neg max: 0.71
# single_baseline max: 0.69
# single_forward max: 0.68
# baseline max: 0.67
# direction max: 0.65
# forward_negation max: 0.64
# single_backward max: 0.4

# %%
k = 3
aggregate_path_glob = f'{ROOT}/aggregated/**/merge_cot_of_majority_answer/summary/merge_answer_hard_*_path_select_{path_selection}_{k}hop.pkl'

metrics_dict, aggregation_types, merge_cot_types = get_metrics_dict_for_path_selection_type(aggregate_path_glob, path_selection)
columns = ['Aggregation Type'] + merge_cot_types

metric = "avg_label_acc"
plot_bar_chart(metric, columns, metrics_dict, aggregation_types, merge_cot_types, title=f"{k} hop {metric}")
# Out:
# ...
# of_majority_answer/summary/merge_answer_hard_merge_cot_none max: 0.98
# of_majority_answer/summary/merge_answer_hard_merge_cot_intersection max: 0.98
# of_majority_answer/summary/merge_answer_hard_merge_cot_longest max: 0.98
# of_majority_answer/summary/merge_answer_hard_merge_cot_union max: 0.98
# ...
# forward_negation max: 0.98
# single_forward max: 0.96
# baseline max: 0.95
# single_baseline max: 0.95
# direction max: 0.94
# backward_negation max: 0.93
# single_backward_neg max: 0.92
# single_forward_neg max: 0.92
# single_backward max: 0.75

# %%
metric = "avg_cot_acc"
plot_bar_chart(metric, columns, metrics_dict, aggregation_types, merge_cot_types, title=f"{k} hop {metric}")
# Out:
# ...
# of_majority_answer/summary/merge_answer_hard_merge_cot_none max: 0.32
# of_majority_answer/summary/merge_answer_hard_merge_cot_union max: 0.32
# of_majority_answer/summary/merge_answer_hard_merge_cot_longest max: 0.29
# of_majority_answer/summary/merge_answer_hard_merge_cot_intersection max: 0.28
# ...
# forward_negation max: 0.32
# baseline max: 0.3
# single_forward max: 0.28
# single_baseline max: 0.28
# backward_negation max: 0.27
# direction max: 0.26
# single_backward_neg max: 0.24
# single_forward_neg max: 0.24
# single_backward max: 0.01

# %%
k = 5
aggregate_path_glob = f'{ROOT}/aggregated/**/merge_cot_of_majority_answer/summary/merge_answer_hard_*_path_select_{path_selection}_{k}hop.pkl'

metrics_dict, aggregation_types, merge_cot_types = get_metrics_dict_for_path_selection_type(aggregate_path_glob, path_selection)
columns = ['Aggregation Type'] + merge_cot_types

metric = "avg_label_acc"
plot_bar_chart(metric, columns, metrics_dict, aggregation_types, merge_cot_types, title=f"{k} hop {metric}")
# Out:
# ...
# of_majority_answer/summary/merge_answer_hard_merge_cot_intersection max: 0.92
# of_majority_answer/summary/merge_answer_hard_merge_cot_none max: 0.92
# of_majority_answer/summary/merge_answer_hard_merge_cot_union max: 0.92
# of_majority_answer/summary/merge_answer_hard_merge_cot_longest max: 0.92
# ...
# single_backward_neg max: 0.92
# single_forward_neg max: 0.92
# forward_negation max: 0.91
# backward_negation max: 0.9
# baseline max: 0.89
# single_baseline max: 0.88
# direction max: 0.87
# single_forward max: 0.85
# single_backward max: 0.68

# %%
metric = "avg_cot_acc"
plot_bar_chart(metric, columns, metrics_dict, aggregation_types, merge_cot_types, title=f"{k} hop {metric}")
# Out:
# ...
# of_majority_answer/summary/merge_answer_hard_merge_cot_union max: 0.22
# of_majority_answer/summary/merge_answer_hard_merge_cot_intersection max: 0.2
# of_majority_answer/summary/merge_answer_hard_merge_cot_none max: 0.2
# of_majority_answer/summary/merge_answer_hard_merge_cot_longest max: 0.2
# ...
# forward_negation max: 0.22
# single_backward_neg max: 0.2
# single_forward_neg max: 0.2
# backward_negation max: 0.17
# single_forward max: 0.16
# direction max: 0.15
# baseline max: 0.14
# single_baseline max: 0.13
# single_backward max: 0.0
