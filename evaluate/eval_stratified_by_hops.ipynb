# %%
from eval_utils import get_metrics_dict_for_path_selection_type, plot_bar_chart

ROOT = "/sailhome/esui/cs224u_final_project/prontoqa_output/fictional"

# %%
# Each plot is for a single hop number
# Same thing as usual otherwise
path_selection = "longest"
k = 1
aggregate_path_glob = f'{ROOT}/aggregated/**/summary/merge_answer_hard_*_path_select_{path_selection}_{k}hop.pkl'

metrics_dict, aggregation_types, merge_cot_types = get_metrics_dict_for_path_selection_type(aggregate_path_glob, path_selection)
columns = ['Aggregation Type'] + merge_cot_types

metric = "avg_label_acc"
plot_bar_chart(metric, columns, metrics_dict, aggregation_types, merge_cot_types, title=f"{k} hop {metric}")
# Out:
# ================================================================================
# intersection max: 0.96
# majority max: 0.96
# union max: 0.96
# longest max: 0.96
# ================================================================================
# double_backward_negation max: 0.96
# backward_negation max: 0.95
# single_backward_neg max: 0.94
# single_forward_neg max: 0.94
# double_forward_negation max: 0.94
# forward_negation max: 0.93
# baseline max: 0.93
# single_baseline max: 0.93
# direction max: 0.92
# all max: 0.91
# single_backward max: 0.9
# single_forward max: 0.9
# forward_randomized_order max: 0.88
# forward_all max: 0.87
# backward_all max: 0.81
# backward_randomized_order max: 0.79

# %%
metric = "avg_cot_acc"
plot_bar_chart(metric, columns, metrics_dict, aggregation_types, merge_cot_types, title=f"{k} hop {metric}")
# Out:
# ================================================================================
# majority max: 0.72
# intersection max: 0.71
# union max: 0.7
# longest max: 0.7
# ================================================================================
# backward_negation max: 0.72
# single_forward_neg max: 0.71
# single_backward_neg max: 0.7
# forward_negation max: 0.7
# direction max: 0.69
# double_forward_negation max: 0.69
# single_baseline max: 0.69
# single_forward max: 0.67
# baseline max: 0.64
# forward_all max: 0.6
# double_backward_negation max: 0.53
# all max: 0.53
# forward_randomized_order max: 0.5
# backward_all max: 0.46
# single_backward max: 0.4
# backward_randomized_order max: 0.32

# %%
k = 3
aggregate_path_glob = f'{ROOT}/aggregated/**/summary/merge_answer_hard_*_path_select_{path_selection}_{k}hop.pkl'

metrics_dict, aggregation_types, merge_cot_types = get_metrics_dict_for_path_selection_type(aggregate_path_glob, path_selection)
columns = ['Aggregation Type'] + merge_cot_types

metric = "avg_label_acc"
plot_bar_chart(metric, columns, metrics_dict, aggregation_types, merge_cot_types, title=f"{k} hop {metric}")
# Out:
# ================================================================================
# majority max: 0.98
# intersection max: 0.98
# union max: 0.98
# longest max: 0.98
# ================================================================================
# forward_negation max: 0.98
# double_forward_negation max: 0.97
# single_forward max: 0.96
# baseline max: 0.95
# single_baseline max: 0.95
# direction max: 0.94
# backward_negation max: 0.93
# single_backward_neg max: 0.92
# single_forward_neg max: 0.92
# forward_randomized_order max: 0.9
# forward_all max: 0.9
# double_backward_negation max: 0.9
# all max: 0.89
# single_backward max: 0.75
# backward_all max: 0.7
# backward_randomized_order max: 0.67

# %%
metric = "avg_cot_acc"
plot_bar_chart(metric, columns, metrics_dict, aggregation_types, merge_cot_types, title=f"{k} hop {metric}")
# Out:
# ================================================================================
# union max: 0.29
# majority max: 0.28
# intersection max: 0.28
# longest max: 0.28
# ================================================================================
# forward_negation max: 0.29
# single_forward max: 0.28
# single_baseline max: 0.28
# direction max: 0.27
# double_forward_negation max: 0.27
# baseline max: 0.26
# forward_randomized_order max: 0.25
# backward_negation max: 0.25
# single_backward_neg max: 0.24
# forward_all max: 0.24
# single_forward_neg max: 0.24
# all max: 0.21
# double_backward_negation max: 0.16
# backward_all max: 0.14
# backward_randomized_order max: 0.03
# single_backward max: 0.01

# %%
k = 5
aggregate_path_glob = f'{ROOT}/aggregated/**/summary/merge_answer_hard_*_path_select_{path_selection}_{k}hop.pkl'

metrics_dict, aggregation_types, merge_cot_types = get_metrics_dict_for_path_selection_type(aggregate_path_glob, path_selection)
columns = ['Aggregation Type'] + merge_cot_types

metric = "avg_label_acc"
plot_bar_chart(metric, columns, metrics_dict, aggregation_types, merge_cot_types, title=f"{k} hop {metric}")
# Out:
# ================================================================================
# intersection max: 0.93
# majority max: 0.93
# longest max: 0.93
# union max: 0.93
# ================================================================================
# double_forward_negation max: 0.93
# single_backward_neg max: 0.92
# single_forward_neg max: 0.92
# forward_negation max: 0.91
# backward_negation max: 0.9
# baseline max: 0.89
# single_baseline max: 0.88
# direction max: 0.87
# double_backward_negation max: 0.87
# single_forward max: 0.85
# all max: 0.78
# forward_all max: 0.77
# forward_randomized_order max: 0.76
# single_backward max: 0.68
# backward_all max: 0.65
# backward_randomized_order max: 0.57

# %%
metric = "avg_cot_acc"
plot_bar_chart(metric, columns, metrics_dict, aggregation_types, merge_cot_types, title=f"{k} hop {metric}")
# Out:
# ================================================================================
# intersection max: 0.22
# majority max: 0.22
# longest max: 0.22
# union max: 0.22
# ================================================================================
# double_forward_negation max: 0.22
# forward_negation max: 0.21
# single_backward_neg max: 0.2
# single_forward_neg max: 0.2
# single_forward max: 0.16
# backward_negation max: 0.14
# double_backward_negation max: 0.14
# baseline max: 0.14
# direction max: 0.13
# single_baseline max: 0.13
# forward_all max: 0.11
# forward_randomized_order max: 0.1
# all max: 0.09
# backward_all max: 0.07
# backward_randomized_order max: 0.05
# single_backward max: 0.0
